# %%
import pickle

# %%
with open('cnn_1min2.txt', 'rb') as f:
    response = pickle.load(f)
    
response
# Out:
# results {
#   alternatives {
# ...

# %%
# response.results[0].alternatives[0].words[0].word

for result in response.results[:4]:
    if result.channel_tag == 1:
        print('\n')
        for alternative in result.alternatives:
            for word in alternative.words:
                print(word.word, end=' ')
# Out:
# 가장 많이 사용되는 뉴럴넷 중에 하나인 cnn 을 이용해서 직접 구해 보도록 하겠습니다 우리가 사용하는 모든 소스코드는 여기에서 보실 수가 있고요 그리고 많은 분들과 개발하고 있습니다 이제 cnn 4시라고 보이는 것은 이미지와 텍스트 볼륨 여러 가지 분야에서 굉장히 좋은 성능을 발휘 하게되는데요 여기서 크게 한 세 가지로 나누어 볼 수가 있습니다 우선 어떤 입력된 이미지 입력된 100타를 컨볼루션 일하는 첫 번째의 컨볼루션 이라는 방법을 통해서 이런 필터를 사용하는 방법이죠 그래서 여기서 여러가지 컨볼루션의 여러 값들을 뽑아내고 요 뽑아낸 갑술 보통은 양이 대상이 많으십니까 그래서 좀 작게 서버 샘플링을 합니다
#
# 유튜브에 두 번째 과정이 과정 있고요 뱃살 좀 작게 만든다는 이야기지요 이런 걸 여러분 한 번 반복한 다음에 세 번째로는 이런 형태의 마지막으로 이렇게 나와 진 값들

# %%
for result in response.results:
        print('\n')
        for alternative in result.alternatives:
            for word in alternative.words:
                start_time = word.start_time.seconds + word.start_time.nanos / 10**9
                end_time = word.end_time.seconds + word.end_time.nanos / 10**9
                print(f'{start_time}~{end_time} : {word.word}')
# Out:
# 0.2~1.4 : 가장
# 1.4~1.6 : 많이
# 1.6~2.1 : 사용되는
# 2.1~2.4 : 뉴럴넷
# 2.4~2.7 : 중에
# 2.7~3.1 : 하나인
# 3.1~3.9 : cnn
# 3.9~4.1 : 을
# 4.1~5.1 : 이용해서
# 5.1~5.7 : 직접
# 5.7~6.0 : 구해
# 6.0~6.2 : 보도록
# 6.2~6.6 : 하겠습니다
# 6.6~7.9 : 우리가
# 7.9~8.1 : 사용하는
# 8.1~8.5 : 모든
# 8.5~9.2 : 소스코드는
# 9.2~9.6 : 여기에서
# 9.6~10.0 : 보실
# 10.0~10.1 : 수가
# 10.1~10.4 : 있고요
# 10.4~10.7 : 그리고
# 10.7~11.0 : 많은
# 11.0~11.4 : 분들과
# 11.4~12.9 : 개발하고
# 12.9~13.1 : 있습니다
# 13.1~14.8 : 이제
# 14.8~15.4 : cnn
# 15.4~16.7 : 4시라고
# 16.7~17.1 : 보이는
# 17.1~17.3 : 것은
# 17.3~18.6 : 이미지와
# 18.6~19.6 : 텍스트분류
# 19.6~20.0 : 여러
# 20.0~20.2 : 가지
# 20.2~20.4 : 분야에서
# 20.4~21.1 : 굉장히
# 21.1~21.5 : 좋은
# 21.5~21.8 : 성능을
# 21.8~22.1 : 발휘
# 22.1~22.7 : 하게되는데요
# 22.7~23.7 : 여기서
# 23.7~23.9 : 크게
# 23.9~24.1 : 한
# 24.1~24.2 : 세
# 24.2~24.6 : 가지로
# 24.6~24.9 : 나누어
# 24.9~25.0 : 볼
# 25.0~25.1 : 수가
# 25.1~25.5 : 있습니다
# 25.5~25.9 : 우선
# 25.9~26.6 : 어떤
# 26.6~27.1 : 입력된
# 27.1~27.5 : 이미지
# 27.5~27.7 : 떠
# 27.7~28.1 : 입력된
# 28.1~28.5 : 100타를
# 28.5~29.4 : 컨볼루션
# ...

# %%
from datetime import time

def gen():
    for result in response.results:
        for alternative in result.alternatives:
            for word in alternative.words:
                start_time = sec2time(word.start_time.seconds, word.start_time.nanos / 10**3)
                end_time = sec2time(word.end_time.seconds, word.end_time.nanos / 10**3)
                yield (word.word, start_time, end_time)
                
def sec2time(sec, micro_sec):
    h, rem = divmod(sec, 3600)
    m, s = divmod(rem, 60)
    return time(h, m, s, int(micro_sec))

# %%
for word, start_at, end_at in gen():
    print(word, start_at, end_at)
# Out:
# 가장 00:00:00.200000 00:00:01.400000
# 많이 00:00:01.400000 00:00:01.600000
# 사용되는 00:00:01.600000 00:00:02.100000
# 뉴럴넷 00:00:02.100000 00:00:02.400000
# 중에 00:00:02.400000 00:00:02.700000
# 하나인 00:00:02.700000 00:00:03.100000
# cnn 00:00:03.100000 00:00:03.900000
# 을 00:00:03.900000 00:00:04.100000
# 이용해서 00:00:04.100000 00:00:05.100000
# 직접 00:00:05.100000 00:00:05.700000
# 구해 00:00:05.700000 00:00:06
# 보도록 00:00:06 00:00:06.200000
# 하겠습니다 00:00:06.200000 00:00:06.600000
# 우리가 00:00:06.600000 00:00:07.900000
# 사용하는 00:00:07.900000 00:00:08.100000
# 모든 00:00:08.100000 00:00:08.500000
# 소스코드는 00:00:08.500000 00:00:09.200000
# 여기에서 00:00:09.200000 00:00:09.600000
# 보실 00:00:09.600000 00:00:10
# 수가 00:00:10 00:00:10.100000
# 있고요 00:00:10.100000 00:00:10.400000
# 그리고 00:00:10.400000 00:00:10.700000
# 많은 00:00:10.700000 00:00:11
# 분들과 00:00:11 00:00:11.400000
# 개발하고 00:00:11.400000 00:00:12.900000
# 있습니다 00:00:12.900000 00:00:13.100000
# 이제 00:00:13.100000 00:00:14.800000
# ...

# %%
sec2time(50.0, 600000)
# Out:
# 0.0 0.0 50.0 600000
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-f4462f222507> in <module>
# ----> 1 sec2time(50.0, 600000)
#
# <ipython-input-11-b718ab712686> in sec2time(sec, micro_sec)
#      13     m, s = divmod(rem, 60)
#      14     print(h, m ,s, micro_sec)
# ---> 15     return time(h, m, s, micro_sec)
#
# TypeError: integer argument expected, got float
